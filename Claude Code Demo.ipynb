# %% [markdown]
# **Some Crappy Notebook**
#
# Just some notebook to pull some eviction data.

# %%
import requests, pandas as pd, json
u="https://data.sfgov.org/api/v3/views/5cei-gny5/query.json"
# Out:
# StatementMeta(, 776000e8-2b6a-4110-8def-636f15d6f28a, 4, Finished, Available, Finished)

# %%
import pandas as pd

url = "https://data.sfgov.org/resource/5cei-gny5.json"

df = pd.read_json(url)
df.head()
# Out:
# StatementMeta(, 776000e8-2b6a-4110-8def-636f15d6f28a, 8, Finished, Available, Finished)
#   eviction_id                    address           city state      zip  \
# 0     RE01296            3400 Block Of B  San Francisco    CA   9413.0
# 1     M2K1620  1000 Block Of 29th Avenue  San Francisco    CA  94122.0
# 2     M050324                        NaN  San Francisco    CA    941.0
# 3     E982496    200 Block Of New Street  San Francisco    CA  94112.0
# 4     E990090                        NaN  San Francisco    CA      NaN
#
#                  file_date  non_payment  breach  nuisance  illegal_use  ...  \
# 0  1997-02-26T00:00:00.000        False   False     False        False  ...
# 1  2000-08-14T00:00:00.000        False   False      True        False  ...
# 2  2005-02-28T00:00:00.000        False   False      True        False  ...
# 3  1998-10-23T00:00:00.000        False   False     False        False  ...
# ...

# %%
df.columns
# Out:
# StatementMeta(, 776000e8-2b6a-4110-8def-636f15d6f28a, 9, Finished, Available, Finished)
# Index(['eviction_id', 'address', 'city', 'state', 'zip', 'file_date',
#        'non_payment', 'breach', 'nuisance', 'illegal_use',
#        'failure_to_sign_renewal', 'access_denial', 'unapproved_subtenant',
#        'owner_move_in', 'demolition', 'capital_improvement',
#        'substantial_rehab', 'ellis_act_withdrawal', 'condo_conversion',
#        'roommate_same_unit', 'other_cause', 'late_payments',
#        'lead_remediation', 'development', 'good_samaritan_ends', 'data_as_of',
#        'data_loaded_at', 'client_location', 'shape',
#        ':@computed_region_bh8s_q3mv', 'supervisor_district', 'neighborhood',
#        ':@computed_region_6qbp_sg9q', ':@computed_region_qgnn_b9vv',
#        ':@computed_region_26cr_cadq', ':@computed_region_ajp5_b2md',
#        ':@computed_region_fyvs_ahh9', ':@computed_region_p5aj_wyqh',
#        ':@computed_region_rxqg_mtj9', ':@computed_region_yftq_j783',
# ...
